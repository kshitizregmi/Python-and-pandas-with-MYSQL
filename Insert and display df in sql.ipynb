# %%
import pandas as pd
import sqlalchemy 
engine = sqlalchemy.create_engine("mysql+pymysql://root:regmi951@localhost:3306/kshitiz")

# %%
userdata = {'USER_ID':[7,7,7,8,8,8],'displayed_article_ID':[1,22,333,22,1,7],'official_link_clicked':[False , True , False ,True ,False,True],'saved_status':[True,True,True,False , False , True]
           ,'relevent':[True,False ,True ,True ,False ,False],'irrevelent':[False,False,True,True,False,False]}
usrdf= pd.DataFrame.from_dict(userdata) #dataframe

# %%
usrdf.to_sql(
    name='user_data', # database table name
    con=engine,
    if_exists='append',
    index=False
)

# %%
df = pd.read_sql_table('user_data',engine)

# %%
df
# Out:
#     USER_ID  displayed_article_ID  official_link_clicked  saved_status  \
# 0         7                     1                      0             1
# 1         7                    22                      1             1
# 2         7                   333                      0             1
# 3         8                    22                      1             0
# 4         8                     1                      0             0
# 5         8                     7                      1             1
# 6         7                     1                      0             1
# 7         7                    22                      1             1
# 8         7                   333                      0             1
# 9         8                    22                      1             0
# 10        8                     1                      0             0
# 11        8                     7                      1             1
# ...

# %%
usrdf
# Out:
#    USER_ID  displayed_article_ID  official_link_clicked  saved_status  \
# 0        7                     1                  False          True
# 1        7                    22                   True          True
# 2        7                   333                  False          True
# 3        8                    22                   True         False
# 4        8                     1                  False         False
# 5        8                     7                   True          True
#
#    relevent  irrevelent
# 0      True       False
# 1     False       False
# 2      True        True
# 3      True        True
# 4     False       False
# 5     False       False

# %%
pd.read_sql('SELECT * FROM user_data where USER_ID = 7',engine)
# Out:
#    USER_ID  displayed_article_ID  official_link_clicked  saved_status  \
# 0        7                     1                      0             1
# 1        7                    22                      1             1
# 2        7                   333                      0             1
# 3        7                     1                      0             1
# 4        7                    22                      1             1
# 5        7                   333                      0             1
# 6        7                     1                      0             1
# 7        7                    22                      1             1
# 8        7                   333                      0             1
#
#    relevent  irrevelent
# 0         1           0
# 1         0           0
# 2         1           1
# 3         1           0
# 4         0           0
# 5         1           1
# 6         1           0
# 7         0           0
# 8         1           1
